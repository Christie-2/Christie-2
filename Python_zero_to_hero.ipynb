# %% [markdown]
# <a href="https://colab.research.google.com/github/Christie-2/Christie-2/blob/main/Python_zero_to_hero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#accessing help and object types
help(max)
a=1+9
type(a)
print(a)
if a==2:print("yes")
if a!=2:print("no")
# Out:
# 10
# no

# %%
#importing packages
import pandas
import numpy
from pandas import DataFrame

# %%
#the working directory
#the working directory
import os
os.getcwd()
cwd=os.getcwd()
print(cwd)
print(type(cwd))
# Out:
# /content
# <class 'str'>

# %%
#changing the cwd

import os
from pathlib import Path
cwd = Path.cwd()
print(cwd)

os.chdir(cwd.parent)
cwd=path.cwd()
print(cwd)
# Out:
# /content

# %%
import pandas as pd
pd
import numpy as np
from pandas import DataFrame

# %%
#Creating data frame
import pandas as pd
data=pd.DataFrame({
    'model':['benz','toyota','subaru','volkswagen','audi','porsche','mazda','lexus'],
    'type':['myback','corolla','impreza','sport/jetta','sedan','cayenne','cx3','ls/es'],
    'year':[2020,2021,2025,2023,2019,2020,2025,2018],
    'price':[800,400,900,300,1200,3400,7800,8900]})

data2=pd.DataFrame({
    'model':['benz','toyota','subaru','volkswagen','audi','porsche'],
    'type':['myback','corolla','impreza','sport/jetta','sedan','cayenne'],
    'year':[2020,2021,2025,2023,2019,2025],
    'price':[800,400,900,300,1200,3400]})
data2

data
# Out:
#         model         type  year  price
# 0        benz       myback  2020    800
# 1      toyota      corolla  2021    400
# 2      subaru      impreza  2025    900
# 3  volkswagen  sport/jetta  2023    300
# 4        audi        sedan  2019   1200
# 5     porsche      cayenne  2020   3400
# 6       mazda          cx3  2025   7800
# 7       lexus        ls/es  2018   8900

# %%
print(data)
print(data2)
# Out:
#         model         type  year  price
# 0        benz       myback  2020    800
# 1      toyota      corolla  2021    400
# 2      subaru      impreza  2025    900
# 3  volkswagen  sport/jetta  2023    300
# 4        audi        sedan  2019   1200
# 5     porsche      cayenne  2020   3400
# 6       mazda          cx3  2025   7800
# 7       lexus        ls/es  2018   8900
#         model         type  year  price
# 0        benz       myback  2020    800
# 1      toyota      corolla  2021    400
# 2      subaru      impreza  2025    900
# 3  volkswagen  sport/jetta  2023    300
# 4        audi        sedan  2019   1200
# 5     porsche      cayenne  2025   3400

# %%
concat=pd.concat([data,data2])
concat
# Out:
#         model         type  year  price
# 0        benz       myback  2020    800
# 1      toyota      corolla  2021    400
# 2      subaru      impreza  2025    900
# 3  volkswagen  sport/jetta  2023    300
# 4        audi        sedan  2019   1200
# 5     porsche      cayenne  2020   3400
# 6       mazda          cx3  2025   7800
# 7       lexus        ls/es  2018   8900
# 0        benz       myback  2020    800
# 1      toyota      corolla  2021    400
# 2      subaru      impreza  2025    900
# 3  volkswagen  sport/jetta  2023    300
# 4        audi        sedan  2019   1200
# 5     porsche      cayenne  2025   3400

# %%
import pandas as pd

Noduplicate= pd.DataFrame.drop_duplicates(concat)
Noduplicate
# Out:
#         model         type  year  price
# 0        benz       myback  2020    800
# 1      toyota      corolla  2021    400
# 2      subaru      impreza  2025    900
# 3  volkswagen  sport/jetta  2023    300
# 4        audi        sedan  2019   1200
# 5     porsche      cayenne  2020   3400
# 6       mazda          cx3  2025   7800
# 7       lexus        ls/es  2018   8900
# 5     porsche      cayenne  2025   3400

# %%
NODUP=concat.drop_duplicates(concat)
NODUP
# Out:
#         model         type  year  price
# 0        benz       myback  2020    800
# 1      toyota      corolla  2021    400
# 2      subaru      impreza  2025    900
# 3  volkswagen  sport/jetta  2023    300
# 4        audi        sedan  2019   1200
# 5     porsche      cayenne  2020   3400
# 6       mazda          cx3  2025   7800
# 7       lexus        ls/es  2018   8900
# 5     porsche      cayenne  2025   3400

# %%
# @title model vs price

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(NODUP['model'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(NODUP, x='price', y='model', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-36-cf976b7a035e>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(NODUP, x='price', y='model', inner='stick', palette='Dark2')

# %%
# @title price

from matplotlib import pyplot as plt
NODUP['price'].plot(kind='line', figsize=(8, 4), title='price')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title model vs type

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['type'].value_counts()
    for x_label, grp in NODUP.groupby('model')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('model')
_ = plt.ylabel('type')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: Using dataframe concat: year vs price plot

import altair as alt

# Create the Altair chart
chart = alt.Chart(concat).mark_circle().encode(
    x='year',  # X-axis: year
    y='price'   # Y-axis: price
)

chart
# Out:
# alt.Chart(...)

# %%
print(concat)
# Out:
#         model         type  year  price
# 0        benz       myback  2020    800
# 1      toyota      corolla  2021    400
# 2      subaru      impreza  2025    900
# 3  volkswagen  sport/jetta  2023    300
# 4        audi        sedan  2019   1200
# 5     porsche      cayenne  2020   3400
# 6       mazda          cx3  2025   7800
# 7       lexus        ls/es  2018   8900
# 0        benz       myback  2020    800
# 1      toyota      corolla  2021    400
# 2      subaru      impreza  2025    900
# 3  volkswagen  sport/jetta  2023    300
# 4        audi        sedan  2019   1200
# 5     porsche      cayenne  2025   3400

# %%
from google.colab import data_table
# !pip install vega_datasets

from vega_datasets import data

Airports=data.airports()
Airports
# Out:
# ...
#      iata                       name              city state country  \
# 0     00M                    Thigpen       Bay Springs    MS     USA
# 1     00R       Livingston Municipal        Livingston    TX     USA
# 2     00V                Meadow Lake  Colorado Springs    CO     USA
# 3     01G               Perry-Warsaw             Perry    NY     USA
# 4     01J           Hilliard Airpark          Hilliard    FL     USA
# ...   ...                        ...               ...   ...     ...
# 3371  ZEF            Elkin Municipal             Elkin    NC     USA
# 3372  ZER  Schuylkill Cty/Joe Zerbey        Pottsville    PA     USA
# 3373  ZPH      Zephyrhills Municipal       Zephyrhills    FL     USA
# 3374  ZUN                 Black Rock              Zuni    NM     USA
# 3375  ZZV       Zanesville Municipal        Zanesville    OH     USA
#
#        latitude   longitude
# 0     31.953765  -89.234505
# 1     30.685861  -95.017928
# 2     38.945749 -104.569893
# ...

# %%
# @title latitude vs longitude

from matplotlib import pyplot as plt
Airports.plot(kind='scatter', x='latitude', y='longitude', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title latitude

from matplotlib import pyplot as plt
Airports['latitude'].plot(kind='hist', bins=20, title='latitude')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title latitude

from matplotlib import pyplot as plt
Airports['latitude'].plot(kind='line', figsize=(8, 4), title='latitude')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data_table.DataTable(Airports,num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iata</th>
#       <th>name</th>
#       <th>city</th>
#       <th>state</th>
#       <th>country</th>
#       <th>latitude</th>
#       <th>longitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>00M</td>
#       <td>Thigpen</td>
#       <td>Bay Springs</td>
#       <td>MS</td>
#       <td>USA</td>
#       <td>31.953765</td>
#       <td>-89.234505</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>00R</td>
#       <td>Livingston Municipal</td>
#       <td>Livingston</td>
#       <td>TX</td>
#       <td>USA</td>
#       <td>30.685861</td>
#       <td>-95.017928</td>
# ...

# %%
data_table.DataTable(Airports,include_index=False,num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iata</th>
#       <th>name</th>
#       <th>city</th>
#       <th>state</th>
#       <th>country</th>
#       <th>latitude</th>
#       <th>longitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>00M</td>
#       <td>Thigpen</td>
#       <td>Bay Springs</td>
#       <td>MS</td>
#       <td>USA</td>
#       <td>31.953765</td>
#       <td>-89.234505</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>00R</td>
#       <td>Livingston Municipal</td>
#       <td>Livingston</td>
#       <td>TX</td>
#       <td>USA</td>
#       <td>30.685861</td>
#       <td>-95.017928</td>
# ...
